# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Varni\Downloads\uncleaned data.csv")
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN        NaN
# 1    12250000  8960.0       NaN        4.0      4.0      yes         no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN         no
# 4    11410000  7420.0       NaN        1.0      2.0      NaN  Of course
# ..        ...     ...       ...        ...      ...      ...        ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN         no
# 541   1767150     NaN       3.0        1.0      1.0       no       ille
# 542   1750000  3620.0       NaN        NaN      NaN      yes         no
# 543   1750000     NaN       NaN        1.0      1.0       no         no
# 544   1750000  3850.0       3.0        1.0      2.0      NaN        NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# Replace NULL values with user input:

# %%
df.fillna("missing value",inplace=True) #inplace ensures changes are made in the same data frame and a new dataframe is not created
df
# Out:
#         price           area       bedrooms      bathrooms        stories  \
# 0    13300000         7420.0            4.0  missing value            3.0
# 1    12250000         8960.0  missing value            4.0            4.0
# 2    12250000         9960.0            3.0            2.0            2.0
# 3    12215000         7500.0  missing value  missing value  missing value
# 4    11410000         7420.0  missing value            1.0            2.0
# ..        ...            ...            ...            ...            ...
# 540   1820000  missing value            2.0  missing value            1.0
# 541   1767150  missing value            3.0            1.0            1.0
# 542   1750000         3620.0  missing value  missing value  missing value
# 543   1750000  missing value  missing value            1.0            1.0
# 544   1750000         3850.0            3.0            1.0            2.0
#
#           mainroad      guestroom       basement hotwaterheating  \
# ...

# %% [markdown]
# Finding duplicated rows:

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Length: 545, dtype: bool

# %% [markdown]
# Removing duplicate rows:

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         price           area       bedrooms      bathrooms        stories  \
# 0    13300000         7420.0            4.0  missing value            3.0
# 1    12250000         8960.0  missing value            4.0            4.0
# 2    12250000         9960.0            3.0            2.0            2.0
# 3    12215000         7500.0  missing value  missing value  missing value
# 4    11410000         7420.0  missing value            1.0            2.0
# ..        ...            ...            ...            ...            ...
# 540   1820000  missing value            2.0  missing value            1.0
# 541   1767150  missing value            3.0            1.0            1.0
# 542   1750000         3620.0  missing value  missing value  missing value
# 543   1750000  missing value  missing value            1.0            1.0
# 544   1750000         3850.0            3.0            1.0            2.0
#
#           mainroad      guestroom       basement hotwaterheating  \
# ...

# %%
df=pd.read_csv(r"C:\Users\Varni\Downloads\uncleaned data.csv")
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad  guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN        NaN
# 1    12250000  8960.0       NaN        4.0      4.0      yes         no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN         no
# 4    11410000  7420.0       NaN        1.0      2.0      NaN  Of course
# ..        ...     ...       ...        ...      ...      ...        ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN         no
# 541   1767150     NaN       3.0        1.0      1.0       no       ille
# 542   1750000  3620.0       NaN        NaN      NaN      yes         no
# 543   1750000     NaN       NaN        1.0      1.0       no         no
# 544   1750000  3850.0       3.0        1.0      2.0      NaN        NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# Find unique values from mainroad,guestroom,basement,hotwaterheating ,airconditioning and prefarea :

# %%
print(df.mainroad.unique())
print(df.guestroom.unique())
print(df.basement.unique())
print(df.hotwaterheating.unique())
print(df.airconditioning.unique())
print(df.prefarea.unique())
# Out:
# [nan 'yes' 'Of course' 'Indeed' 'yep' 'Haan' 'True' 'y' 'Y' "['y']" 'Nope'
#  'Yo' 'no' 'Haanji' 'Nakko' 'False' 'Naaji' 'N' 'n']
# [nan 'no' 'Of course' 'yes' 'ille' 'y' 'N' 'Yo' 'Nakko' 'Y' 'Naaji' 'n'
#  'False' "['n']" 'Haan' 'Nah' 'yep' 'Haanji' 'True' 'Nope' 'Indeed']
# [nan 'no' 'yes' 'Haanji' 'N' 'Naaji' 'n' 'y' 'False' 'Haan' 'Nakko' 'ille'
#  'Nah' 'True' 'yep' 'Nope' 'Indeed' "['n']" 'Of course' 'Y' 'Yo']
# [nan 'Nakko' 'no' 'Nope' 'yes' 'Nah' 'Y' 'n' 'False' 'Naaji' 'ille' 'N'
#  "['n']" 'Haan' 'y']
# ['yes' 'Naaji' 'no' nan 'yep' 'y' 'True' "['y']" 'Y' "['n']" 'n' 'N'
#  'Nakko' 'Nah' 'ille' 'False' 'Nope' 'Of course' 'Haanji']
# ['Haanji' 'no' 'yes' 'Haan' nan 'Of course' 'Nakko' 'Nope' 'ille' 'N'
#  'yep' 'y' 'Naaji' 'True' 'Y' 'n' "['n']" 'False' 'Yo' 'Nah']

# %% [markdown]
# Replacing all distorted values as yes and no:

# %%
y=['Haanji', 'yes', 'Haan', 'Of course', 'yep', 'y', 'True', 'Y', 'Yo', 'Indeed', "['y']"]
replace_yes='YES'
n=['no', 'Nakko', 'Nope', 'ille', 'N', 'Naaji', 'n', "['n']", 'False', 'Nah', 'Indeed']
replace_no='NO'

df["mainroad"]=df["mainroad"].replace(y,replace_yes)
df["mainroad"]=df["mainroad"].replace(n,replace_no)
df["guestroom"]=df["guestroom"].replace(y,replace_yes)
df["guestroom"]=df["guestroom"].replace(n,replace_no)
df["basement"]=df["basement"].replace(y,replace_yes)
df["basement"]=df["basement"].replace(n,replace_no)
df["hotwaterheating"]=df["hotwaterheating"].replace(y,replace_yes)
df["hotwaterheating"]=df["hotwaterheating"].replace(n,replace_no)
df["airconditioning"]=df["airconditioning"].replace(y,replace_yes)
df["airconditioning"]=df["airconditioning"].replace(n,replace_no)
df["prefarea"]=df["prefarea"].replace(y,replace_yes)
df["prefarea"]=df["prefarea"].replace(n,replace_no)
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN       NaN
# 1    12250000  8960.0       NaN        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN        NO
# 4    11410000  7420.0       NaN        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000     NaN       2.0        NaN      1.0      NaN        NO
# 541   1767150     NaN       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       NaN        NaN      NaN      YES        NO
# 543   1750000     NaN       NaN        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relation between area and price:

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['price'], df['area'])
plt.xlabel('price')
plt.ylabel('area')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price'] < 5000000 and np.isnan(df.loc[i, 'area']):
        df.loc[i,'area'] = 4000
    elif df.loc[i,'price'] < 6000000 and np.isnan(df.loc[i, 'area']):
        df.loc[i,'area'] = 5000
    elif df.loc[i,'price'] < 8000000 and np.isnan(df.loc[i, 'area']):
        df.loc[i,'area'] = 6000
    elif df.loc[i,'price'] <10000000 and np.isnan(df.loc[i, 'area']):
        df.loc[i,'area'] = 9000
    elif np.isnan(df.loc[i, 'area']):
        df.loc[i,'area'] = 3000
    else:
        continue

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN       NaN
# 1    12250000  8960.0       NaN        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       NaN        NaN      NaN      NaN        NO
# 4    11410000  7420.0       NaN        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        NaN      1.0      NaN        NO
# 541   1767150  4000.0       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       NaN        NaN      NaN      YES        NO
# 543   1750000  4000.0       NaN        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# findind relation between area and bedroom:

# %%
plt.scatter(df['area'],df['bedrooms'])
plt.xlabel('area')
plt.ylabel('bedrooms')
plt.show()
#not any visible relation

# %%
plt.scatter(df['price'],df['bedrooms'])
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.show()
#not any visible relation

# %%
df['bedrooms'].fillna(df['bedrooms'].mode()[0],inplace=True)
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        NaN      3.0      NaN       NaN
# 1    12250000  8960.0       3.0        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       3.0        NaN      NaN      NaN        NO
# 4    11410000  7420.0       3.0        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        NaN      1.0      NaN        NO
# 541   1767150  4000.0       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       3.0        NaN      NaN      YES        NO
# 543   1750000  4000.0       3.0        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# relation between bedroms and bathrooms:

# %%
plt.scatter(df['bedrooms'],df['bathrooms'])
plt.xlabel('bedrooms')
plt.ylabel('bathrooms')
plt.show() #not any visible relation

# %%
plt.scatter(df['area'],df['bathrooms'])
plt.xlabel('area')
plt.ylabel('bathrooms')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'area']<8000 and np.isnan(df.loc[i,'bathrooms']):
        df.loc[i,'bathrooms'] = 1
    elif np.isnan(df.loc[i, 'bathrooms']):
        df.loc[i,'bathrooms'] = 2

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0      NaN       NaN
# 1    12250000  8960.0       3.0        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       3.0        1.0      NaN      NaN        NO
# 4    11410000  7420.0       3.0        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0      NaN        NO
# 541   1767150  4000.0       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       3.0        1.0      NaN      YES        NO
# 543   1750000  4000.0       3.0        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relation of stories:

# %%
plt.scatter(df['bedrooms'],df['stories'])
plt.xlabel('bedrooms')
plt.ylabel('stories')
plt.show() #not any visible relation

# %%
plt.scatter(df['area'],df['stories'])
plt.xlabel('area')
plt.ylabel('stories')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'area']<9000 and np.isnan(df.loc[i,'stories']):
        df.loc[i,'stories'] = 2
    elif np.isnan(df.loc[i, 'stories']):
        df.loc[i,'stories'] = 1

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0      NaN       NaN
# 1    12250000  8960.0       3.0        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES       NaN
# 3    12215000  7500.0       3.0        1.0      2.0      NaN        NO
# 4    11410000  7420.0       3.0        1.0      2.0      NaN       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0      NaN        NO
# 541   1767150  4000.0       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       3.0        1.0      2.0      YES        NO
# 543   1750000  4000.0       3.0        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# converting strings to numbers for ease of understanding:

# %%
for i in df.columns: 
    for j in df.index:
        if df.loc[j,i]=='YES':
            df.loc[j,i]=1
        elif df.loc[j,i]=='NO':
            df.loc[j,i]=0
        elif df.loc[j,i]=='furnished':
            df.loc[j,i]=1
        elif df.loc[j,i]=='unfurnished':
            df.loc[j,i]=0
        elif  df.loc[j,i]=='semi-furnished':
             df.loc[j,i]=2

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0      NaN       NaN
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1       NaN
# 3    12215000  7500.0       3.0        1.0      2.0      NaN         0
# 4    11410000  7420.0       3.0        1.0      2.0      NaN         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0      NaN         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0      NaN       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relations of mainroad:

# %%
plt.scatter(df['price'],df['mainroad'])
plt.xlabel('price')
plt.ylabel('mainroad')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price']<5000000 and np.isnan(df.loc[i,'mainroad']):
        df.loc[i,'mainroad'] = 0
    elif np.isnan(df.loc[i, 'mainroad']):
        df.loc[i,'mainroad'] = 1

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1       NaN
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1       NaN
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0       NaN
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relations of guestroom:

# %%
plt.scatter(df['bedrooms'],df['guestroom'])
plt.xlabel('bedrooms')
plt.ylabel('guestroom')
plt.show() #no visible relation

# %%
plt.scatter(df['price'],df['guestroom'])
plt.xlabel('price')
plt.ylabel('guestroom')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price']>4000000 and df.loc[i,'price']<6500000 and np.isnan(df.loc[i,'mainroad']):
        df.loc[i,'guestroom'] = 1
    elif np.isnan(df.loc[i, 'guestroom']):
        df.loc[i,'guestroom'] = 0

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relations of basement:

# %%
plt.scatter(df['stories'],df['basement'])
plt.xlabel('stories')
plt.ylabel('basement')
plt.show() #no visible relation

# %%
plt.scatter(df['price'],df['basement'])
plt.xlabel('price')
plt.ylabel('basement')
plt.show()

# %%
df['basement'].fillna(0,inplace=True)
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relation of hotwaterheating:

# %%
plt.scatter(df['price'],df['hotwaterheating'])
plt.xlabel('price')
plt.ylabel('hotwaterheating')
plt.show()

# %%
df['hotwaterheating'].fillna(0,inplace=True)
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement  hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relations of airconditioning:

# %%
plt.scatter(df['price'],df['airconditioning'])
plt.xlabel('price')
plt.ylabel('airconditioning')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price']<3000000 and np.isnan(df.loc[i,'airconditioning']):
        df.loc[i,'airconditioning'] = 0
    elif np.isnan(df.loc[i, 'airconditioning']):
        df.loc[i,'airconditioning'] = 1
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement  hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# finding relations of parking:

# %%
plt.scatter(df['price'],df['parking'])
plt.xlabel('price')
plt.ylabel('parking')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price']<6000000 and np.isnan(df.loc[i,'parking']):
        df.loc[i,'parking'] = 0
    if df.loc[i,'price']>6000000 and df.loc[i,'price']<10000000 and np.isnan(df.loc[i,'parking']):
         df.loc[i,'parking']=1
    elif np.isnan(df.loc[i, 'parking']):
        df.loc[i,'parking'] = 2

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement  hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df['prefarea'].fillna(df['prefarea'].mode()[0],inplace=True)
df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement  hotwaterheating airconditioning  parking  prefarea  \
# ...

# %% [markdown]
# finding relations of furnishing status:

# %%
plt.scatter(df['price'],df['furnishingstatus'])
plt.xlabel('price')
plt.ylabel('furnishingstatus')
plt.show()

# %%
for i in df.index:
    if df.loc[i,'price']<6000000 and np.isnan(df.loc[i,'furnishingstatus']):
        df.loc[i,'furnishingstatus'] = 0
    if df.loc[i,'price']>6000000 and df.loc[i,'price']<10000000 and np.isnan(df.loc[i,'furnishingstatus']):
        df.loc[i,'furnishingstatus']=1
    if np.isnan(df.loc[i, 'furnishingstatus']):
        df.loc[i,'furnishingstatus'] = 2

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0        1         0
# 1    12250000  8960.0       3.0        4.0      4.0        1         0
# 2    12250000  9960.0       3.0        2.0      2.0        1         0
# 3    12215000  7500.0       3.0        1.0      2.0        1         0
# 4    11410000  7420.0       3.0        1.0      2.0        1         1
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0        0         0
# 541   1767150  4000.0       3.0        1.0      1.0        0         0
# 542   1750000  3620.0       3.0        1.0      2.0        1         0
# 543   1750000  4000.0       3.0        1.0      1.0        0         0
# 544   1750000  3850.0       3.0        1.0      2.0        0         0
#
#      basement  hotwaterheating airconditioning  parking  prefarea  \
# ...

# %%
for j in range(5,10):
    for i in df.index:
        if df.iloc[i,j] == 1:
            df.iloc[i,j] = "YES"
        elif df.iloc[i,j] == 0:
            df.iloc[i,j] = "NO"
            
        if df.loc[i,'prefarea'] == 1:
            df.loc[i,'prefarea'] = "YES"
        elif df.loc[i,'prefarea'] == 0:
            df.loc[i,'prefarea'] = "NO"
            
        if df.loc[i,'furnishingstatus'] == 0:
            df.loc[i,'furnishingstatus'] = "unfurnished"
        elif df.loc[i,'furnishingstatus'] == 2:
            df.loc[i,'furnishingstatus'] = "semi-furnished"
        elif df.loc[i,'furnishingstatus'] == 1:
            df.loc[i,'furnishingstatus'] = "furnished"

df
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        1.0      3.0      YES        NO
# 1    12250000  8960.0       3.0        4.0      4.0      YES        NO
# 2    12250000  9960.0       3.0        2.0      2.0      YES        NO
# 3    12215000  7500.0       3.0        1.0      2.0      YES        NO
# 4    11410000  7420.0       3.0        1.0      2.0      YES       YES
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  4000.0       2.0        1.0      1.0       NO        NO
# 541   1767150  4000.0       3.0        1.0      1.0       NO        NO
# 542   1750000  3620.0       3.0        1.0      2.0      YES        NO
# 543   1750000  4000.0       3.0        1.0      1.0       NO        NO
# 544   1750000  3850.0       3.0        1.0      2.0       NO        NO
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df.to_csv(r"C:\Users\Varni\Downloads\cleaned data.csv")
